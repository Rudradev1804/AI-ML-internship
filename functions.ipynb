# %%
def greet():
    print("hello raaj")

greet()


def add(a,b):
    result=a+b
    print(result)

add(4,7)
# Out:
# hello raaj
# 11

# %%
def sub(a,b):
    substraction=a-b
    return substraction

answer=substraction
# Out:
# -8

# %%
def greet(name,age):
    print(f"my {name} and my age is {age}")


greet(age=45,name="sumit")
# Out:
# my sumit and my age is 45

# %%
# def calculate(a,b):
#     addition=a+b
#     sub=a-b
#     return addition,sub
    

# print(calculate(2,3))


# def add(a,b):
#     return a+b

# print(add(2,4))


def num(*a):
    print(a)

num(4,7,8,9)
# Out:
# (4, 7, 8, 9)

# %%
def show_info(**details):
    for key,value in details.items():
        print(key,value)
    

show_info(name="sumit",age=45)
# Out:
# name sumit
# age 45

# %%
## Q-1 Write a function greet() that prints “Hello, welcome to Python class

def greet():
    print()
