# %%
# st={1,2,3,4,1,1,1,2,3,4}
# print(st)



# st=set([1,2,34,4,54])
# print(st)

# str=set("helooword")
# print(str)

st={1,2,3,4}
st.add(6)
print(st)


st.update([10,20,30])
print(st)
# Out:
# {1, 2, 3, 4, 6}
# {1, 2, 3, 4, 6, 10, 20, 30}

# %%
st={2,4,6,8}

# st.remove(9)
# print(st)

# st.discard(9)
# print(st)

# st.pop()
# print(st)
# Out:
# {2, 4, 6}

# %%
set={10,20,30,40}

# for i in set:
#     print(i)


print(10 in set)
# Out:
# True

# %%
a={1,2,3,4,5}
b={4,5,6,8,9,10,11}

result=a.union(b)
print(result)

# result=a|b

result=a.intersection(b)
print(result)

result=a&b


result=b.difference(a)
print(result)

result=a-b


result=a.symmetric_difference(b)
print(result)
# Out:
# {1, 2, 3, 4, 5, 6, 8, 9, 10, 11}
# {4, 5}
# {6, 8, 9, 10, 11}
# {1, 2, 3, 6, 8, 9, 10, 11}
