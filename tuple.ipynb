# %%
lst=[1,2,3]
lst[0]=10
print(lst)

# tupl=(1,2,3)
# tupl[0]=10
# print(tupl)

tup=(1,1.2,"hello")
# Out:
# [10, 2, 3]

# %%
# t1=(1,2,3)
# t2=("sumit",12,4.6)

# tup=(100,)
# print(type(tup))
# Out:
# <class 'tuple'>

# %%
tup=(10,20,30)
print(tup[-1])


tup=(10,20,30,40,50)
print(tup[::-1])
print(tup[0:-2])
# Out:
# 30
# (50, 40, 30, 20, 10)
# (10, 20, 30)

# %%
tupl=(10,20,30)
lst=list(tupl)
lst[2]=40
tuple=tuple(lst)
print(tuple)
# Out:
# (10, 20, 40)

# %%
t1=(1,2,3)
t2=(4,5,6)
merge=t1+t2
print(merge)


print(4 in t2)
print(4 not in t2)
# Out:
# (1, 2, 3, 4, 5, 6)
# True
# False

# %%
tuple=(1,1,1,1,3,4,5,6,7)
print(tuple.count(1))

print(tuple.index(1))
print(tuple.index(5))

tuple=(10,20,30,40)
print(max(tuple))
print(min(tuple))
print(sum(tuple))
# Out:
# 4
# 0
# 6
# 40
# 10
# 100

# %%
fruits=("apple","bannana","cherry")

for x in fruits:
    print(x)
# Out:
# apple
# bannana
# cherry

# %%
tup=((1,2,3),(4,5,6))
print(tup[1][1])
# Out:
# 5

# %%
student=("raj",23,"btech")

name,age,degree=student

print(degree)
print(age)
# Out:
# btech
# 23
